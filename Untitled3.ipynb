# %%
import pandas as pd

# %%
df = pd.read_excel('/home/konam/Downloads/budget_1920.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.describe()
# Out:
#          Sl. No.  2017-2018 - Actuals  2018-2019 - Budget Estimates  \
# count  17.000000         2.100000e+01                  2.100000e+01
# mean    9.000000         6.085340e+05                  6.805568e+05
# std     5.049752         7.221072e+05                  8.367700e+05
# min     1.000000         4.000000e-01                  3.000000e-01
# 25%     5.000000         6.211200e+04                  4.848100e+04
# 50%     9.000000         2.631400e+05                  3.004410e+05
# 75%    13.000000         7.067420e+05                  7.164750e+05
# max    17.000000         2.141975e+06                  2.442213e+06
#
#        2018-2019 - Revised Estimates  2019-2020 - Budget Estimates
# count                   2.100000e+01                  2.100000e+01
# mean                    6.846113e+05                  7.747349e+05
# std                     8.400286e+05                  9.572081e+05
# min                     2.000000e-01                  2.000000e-01
# ...

# %%
df.columns
# Out:
# Index(['Sl. No.', 'Budget Receipts', '2017-2018 - Actuals',
#        '2018-2019 - Budget Estimates', '2018-2019 - Revised Estimates',
#        '2019-2020 - Budget Estimates'],
#       dtype='object')

# %%
df.head()
# Out:
#    Sl. No.              Budget Receipts  2017-2018 - Actuals  \
# 0      1.0             Revenue Receipts            1435233.0
# 1      2.0  Tax Revenue (Net to Centre)            1242488.0
# 2      3.0              Non Tax Revenue             192745.0
# 3      4.0            Capital Receipts1             706742.0
# 4      5.0            Recovery of Loans              15633.0
#
#    2018-2019 - Budget Estimates  2018-2019 - Revised Estimates  \
# 0                     1725738.0                      1729682.0
# 1                     1480649.0                      1484406.0
# 2                      245089.0                       245276.0
# 3                      716475.0                       727553.0
# 4                       12199.0                        13155.0
#
#    2019-2020 - Budget Estimates
# 0                     1977693.0
# 1                     1705046.0
# 2                      272647.0
# 3                      806507.0
# 4                       12508.0

# %%
df.tail()
# Out:
#     Sl. No.                                Budget Receipts  \
# 16      NaN  Effective Revenue Deficit - Percentage of GDP
# 17     16.0                     Fiscal Deficit [9-(1+5+6)]
# 18      NaN             Fiscal Deficit - Percentage of GDP
# 19     17.0                        Primary Deficit (16-11)
# 20      NaN            Primary Deficit - Percentage of GDP
#
#     2017-2018 - Actuals  2018-2019 - Budget Estimates  \
# 16                  1.5                           1.2
# 17             591064.0                      624276.0
# 18                  3.5                           3.3
# 19              62112.0                       48481.0
# 20                  0.4                           0.3
#
#     2018-2019 - Revised Estimates  2019-2020 - Budget Estimates
# 16                            1.1                           1.3
# 17                       634398.0                      703999.0
# 18                            3.4                           3.4
# ...

# %%
df
# Out:
#     Sl. No.                                Budget Receipts  \
# 0       1.0                               Revenue Receipts
# 1       2.0                    Tax Revenue (Net to Centre)
# 2       3.0                                Non Tax Revenue
# 3       4.0                              Capital Receipts1
# 4       5.0                              Recovery of Loans
# 5       6.0                                 Other Receipts
# 6       7.0              Borrowings and Other Liabilities2
# 7       8.0                          Total Receipts (1+ 4)
# 8       9.0                      Total Expenditure (10+13)
# 9      10.0                    On Revenue Account of which
# 10     11.0                              Interest Payments
# 11     12.0  Grants in Aid for creation of capital assests
# 12     13.0                             On Capital Account
# 13     14.0                         Revenue Deficit (10-1)
# 14      NaN            Revenue Deficit - percentage of GDP
# ...
